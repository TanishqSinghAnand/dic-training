# %%
#Task 1 
n = int(input("Enter a positive integer: "))

sumN = int(n * (n + 1) / 2)

factN = 1
for i in range(1, n + 1):
    factN *= i

isPrime = n > 1
for i in range(2, int(n ** 0.5) + 1):
    if n % i == 0:
        isPrime = False
        break

print("Sum =", sumN)
print("Factorial =", factN)
print("Prime" if isPrime else "Not Prime")
# Out:
# Sum = 15
# Factorial = 120
# Prime

# %%
#Task 2
password = input("Enter password: ")

hasUpper = False
hasLower = False
hasDigit = False

for ch in password:
    if ch.isupper():
        hasUpper = True
    elif ch.islower():
        hasLower = True
    elif ch.isdigit():
        hasDigit = True

if len(password) >= 8 and hasUpper and hasLower and hasDigit:
    print("Strong Password")
else:
    print("Weak Password")

    if len(password) < 8:
        print("Missing: At least 8 characters")
    if not hasUpper:
        print("Missing: Uppercase letter")
    if not hasLower:
        print("Missing: Lowercase letter")
    if not hasDigit:
        print("Missing: Digit")
# Out:
# Weak Password
# Missing: At least 8 characters
# Missing: Uppercase letter

# %%
x = [10, 20, 30]
y = x
y.append(40)
x[1] = 50
print(x)
print(y)
# Out:
# [10, 50, 30, 40]
# [10, 50, 30, 40]

# %%
d = {"A": 10, "B": 20}
d["C"] = d["A"] + d["B"]
del d["B"]
print(len(d))
print(sum(d.values()))
# Out:
# 2
# 40

# %%
def fun(n):
    if n % 2 == 0:
        return "Even"
    return "Odd"
data = [11, 20, 15, 8]
result = {}
for num in data:
    result[num] = fun(num)
print(result)
# Out:
# {11: 'Odd', 20: 'Even', 15: 'Odd', 8: 'Even'}
